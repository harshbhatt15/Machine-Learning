# %%
df = {
    'first': ['John', 'Jane', 'Jim' , 'harsh', 'khushi' , 'heet' , 'neel'],
    'last': ['Doe', 'Smith', 'Beam' , 'bhatt', 'panchal' , 'Shah' , 'Arora'],
    'email': ['johndoe@gmail.com', 'janesmith@gmail.com', 'jimbeam@gmail.com', 'harshbhatt@gmail.com', 'khushipanchal@gmail.com', 'heetshah@gmail.com', 'neelarora@gmail.com']
}

# %%
import pandas as pd
df = pd.DataFrame(df)

# %%
df
# Out:
#     first     last                    email
# 0    John      Doe        johndoe@gmail.com
# 1    Jane    Smith      janesmith@gmail.com
# 2     Jim     Beam        jimbeam@gmail.com
# 3   harsh    bhatt     harshbhatt@gmail.com
# 4  khushi  panchal  khushipanchal@gmail.com
# 5    heet     Shah       heetshah@gmail.com
# 6    neel    Arora      neelarora@gmail.com

# %%
df.info
# Out:
# <bound method DataFrame.info of     first     last                    email
# 0    John      Doe        johndoe@gmail.com
# 1    Jane    Smith      janesmith@gmail.com
# 2     Jim     Beam        jimbeam@gmail.com
# 3   harsh    bhatt     harshbhatt@gmail.com
# 4  khushi  panchal  khushipanchal@gmail.com
# 5    heet     Shah       heetshah@gmail.com
# 6    neel    Arora      neelarora@gmail.com>

# %%
df.shape
# Out:
# (7, 3)

# %%
df.head()
# Out:
#     first     last                    email
# 0    John      Doe        johndoe@gmail.com
# 1    Jane    Smith      janesmith@gmail.com
# 2     Jim     Beam        jimbeam@gmail.com
# 3   harsh    bhatt     harshbhatt@gmail.com
# 4  khushi  panchal  khushipanchal@gmail.com

# %%
df.tail()
# Out:
#     first     last                    email
# 2     Jim     Beam        jimbeam@gmail.com
# 3   harsh    bhatt     harshbhatt@gmail.com
# 4  khushi  panchal  khushipanchal@gmail.com
# 5    heet     Shah       heetshah@gmail.com
# 6    neel    Arora      neelarora@gmail.com

# %%
df[['last','email']]
# Out:
#       last                    email
# 0      Doe        johndoe@gmail.com
# 1    Smith      janesmith@gmail.com
# 2     Beam        jimbeam@gmail.com
# 3    bhatt     harshbhatt@gmail.com
# 4  panchal  khushipanchal@gmail.com
# 5     Shah       heetshah@gmail.com
# 6    Arora      neelarora@gmail.com

# %%
df.iloc[0]
# Out:
# first                 John
# last                   Doe
# email    johndoe@gmail.com
# Name: 0, dtype: object

# %%
df.loc[4]
# Out:
# first                     khushi
# last                     panchal
# email    khushipanchal@gmail.com
# Name: 4, dtype: object

# %%
df.columns = ['First_name','Last_name','E-mail']
df
# Out:
#   First_name Last_name                   E-mail
# 0       John       Doe        johndoe@gmail.com
# 1       Jane     Smith      janesmith@gmail.com
# 2        Jim      Beam        jimbeam@gmail.com
# 3      harsh     bhatt     harshbhatt@gmail.com
# 4     khushi   panchal  khushipanchal@gmail.com
# 5       heet      Shah       heetshah@gmail.com
# 6       neel     Arora      neelarora@gmail.com

# %%
df.columns = [x.upper()for x in df.columns]
df
# Out:
#   FIRST_NAME LAST_NAME                   E-MAIL
# 0       John       Doe        johndoe@gmail.com
# 1       Jane     Smith      janesmith@gmail.com
# 2        Jim      Beam        jimbeam@gmail.com
# 3      harsh     bhatt     harshbhatt@gmail.com
# 4     khushi   panchal  khushipanchal@gmail.com
# 5       heet      Shah       heetshah@gmail.com
# 6       neel     Arora      neelarora@gmail.com

# %%
df.columns = [x.lower()for x in df.columns]
df
# Out:
#   first_name last_name                   e-mail
# 0       John       Doe        johndoe@gmail.com
# 1       Jane     Smith      janesmith@gmail.com
# 2        Jim      Beam        jimbeam@gmail.com
# 3      harsh     bhatt     harshbhatt@gmail.com
# 4     khushi   panchal  khushipanchal@gmail.com
# 5       heet      Shah       heetshah@gmail.com
# 6       neel     Arora      neelarora@gmail.com

# %%
df.columns = df.columns.str.replace('_',' ')

# %%
df
# Out:
#   first name last name                   e-mail
# 0       John       Doe        johndoe@gmail.com
# 1       Jane     Smith      janesmith@gmail.com
# 2        Jim      Beam        jimbeam@gmail.com
# 3      harsh     bhatt     harshbhatt@gmail.com
# 4     khushi   panchal  khushipanchal@gmail.com
# 5       heet      Shah       heetshah@gmail.com
# 6       neel     Arora      neelarora@gmail.com

# %%
df.value_counts()
# Out:
# first name  last name  e-mail
# Jane        Smith      janesmith@gmail.com        1
# Jim         Beam       jimbeam@gmail.com          1
# John        Doe        johndoe@gmail.com          1
# harsh       bhatt      harshbhatt@gmail.com       1
# heet        Shah       heetshah@gmail.com         1
# khushi      panchal    khushipanchal@gmail.com    1
# neel        Arora      neelarora@gmail.com        1
# Name: count, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.set_index('e-mail')
# Out:
#                         first name last name
# e-mail
# johndoe@gmail.com             John       Doe
# janesmith@gmail.com           Jane     Smith
# jimbeam@gmail.com              Jim      Beam
# harshbhatt@gmail.com         harsh     bhatt
# khushipanchal@gmail.com     khushi   panchal
# heetshah@gmail.com            heet      Shah
# neelarora@gmail.com           neel     Arora

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    index first name last name                   e-mail
# 0      0       John       Doe        johndoe@gmail.com
# 1      1       Jane     Smith      janesmith@gmail.com
# 2      2        Jim      Beam        jimbeam@gmail.com
# 3      3      harsh     bhatt     harshbhatt@gmail.com
# 4      4     khushi   panchal  khushipanchal@gmail.com
# 5      5       heet      Shah       heetshah@gmail.com
# 6      6       neel     Arora      neelarora@gmail.com

# %%
df.rename(columns={'first name' : 'first'},inplace=True)
df
# Out:
#    index   first last name                   e-mail
# 0      0    John       Doe        johndoe@gmail.com
# 1      1    Jane     Smith      janesmith@gmail.com
# 2      2     Jim      Beam        jimbeam@gmail.com
# 3      3   harsh     bhatt     harshbhatt@gmail.com
# 4      4  khushi   panchal  khushipanchal@gmail.com
# 5      5    heet      Shah       heetshah@gmail.com
# 6      6    neel     Arora      neelarora@gmail.com

# %%
df.rename(columns={'first' : 'first name'},inplace=True)
df
# Out:
#    index first name last name                   e-mail
# 0      0       John       Doe        johndoe@gmail.com
# 1      1       Jane     Smith      janesmith@gmail.com
# 2      2        Jim      Beam        jimbeam@gmail.com
# 3      3      harsh     bhatt     harshbhatt@gmail.com
# 4      4     khushi   panchal  khushipanchal@gmail.com
# 5      5       heet      Shah       heetshah@gmail.com
# 6      6       neel     Arora      neelarora@gmail.com

# %%
df.rename(columns={'first name' : 'First Name', 'last name' : 'Last Name', 'e-mail' : 'E-mail'}, inplace=True)
df
# Out:
#    index First Name Last Name                   E-mail
# 0      0       John       Doe        johndoe@gmail.com
# 1      1       Jane     Smith      janesmith@gmail.com
# 2      2        Jim      Beam        jimbeam@gmail.com
# 3      3      harsh     bhatt     harshbhatt@gmail.com
# 4      4     khushi   panchal  khushipanchal@gmail.com
# 5      5       heet      Shah       heetshah@gmail.com
# 6      6       neel     Arora      neelarora@gmail.com
